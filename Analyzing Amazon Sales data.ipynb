# %%
  import pandas as pd
import numpy as np
import seaborn as sns #importing libraries

# %%
df = pd.read_excel('C:\\Users\\DELL\\Downloads\\AmazonSalesdata.xlsx')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority           Order Date   Order ID            Ship Date  \
# 95              M            7/26/2011  512878119  2011-03-09 00:00:00
# 96              L  2011-11-11 00:00:00  810711038           12/28/2011
# 97              C  2016-01-06 00:00:00  728815257            6/29/2016
# 98              M            7/30/2015  559427106  2015-08-08 00:00:00
# 99              L  2012-10-02 00:00:00  665095412            2/15/2012
#
#     Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 95         888      109.28      35.84       97040.64    31825.92
# ...

# %%
df.shape
# Out:
# (100, 17)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'Order Year', 'Order Quarter', 'Order Month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
#  14  Order Year      100 non-null    int64
#  15  Order Quarter   100 non-null    int64
#  16  Order Month     100 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df['Item Type'].unique()
# Out:
# array(['Baby Food', 'Cereal', 'Office Supplies', 'Fruits', 'Household',
#        'Vegetables', 'Personal Care', 'Clothes', 'Cosmetics', 'Beverages',
#        'Meat', 'Snacks'], dtype=object)

# %%
df['Order Year'] = pd.DatetimeIndex(df['Order Date']).year 
df['Order Quarter'] = pd.DatetimeIndex(df['Order Date']).quarter 
df['Order Month'] = pd.DatetimeIndex(df['Order Date']).month

# %%
df1=df[['Region','Country','Item Type','Sales Channel','Order Priority','Order Date','Order ID','Ship Date','Units Sold','Unit Price','Unit Cost','Total Revenue','Total Cost','Total Profit','Order Year','Order Quarter','Order Month']]

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
Sort_df1=df1.sort_values(by = ['Units Sold'], ascending=False)

# %%
Items_sold = Sort_df1[['Region', 'Item Type', 'Units Sold','Order Year','Order Quarter', 'Order Month']]

# %%
Items_sold.head(5)
# Out:
#                           Region  Item Type  Units Sold  Order Year  \
# 0          Australia and Oceania  Baby Food        9925        2010
# 56         Australia and Oceania    Clothes        9905        2010
# 74  Middle East and North Africa  Cosmetics        9892        2013
# 79         Australia and Oceania  Cosmetics        9654        2013
# 51            Sub-Saharan Africa     Fruits        9606        2013
#
#     Order Quarter  Order Month
# 0               2            5
# 56              2            6
# 74              2            5
# 79              3            7
# 51              3            8

# %%
Items_sold.tail(5)
# Out:
#                           Region      Item Type  Units Sold  Order Year  \
# 88  Middle East and North Africa         Fruits         522        2012
# 58                        Europe      Household         282        2012
# 47                        Europe  Personal Care         273        2010
# 43                        Europe     Vegetables         171        2012
# 10                          Asia     Vegetables         124        2011
#
#     Order Quarter  Order Month
# 88              2            4
# 58              2            5
# 47              4           12
# 43              2            6
# 10              2            6

# %%
Sort_df2=df1.sort_values(by = ['Total Revenue'], ascending=False)

# %%
Items_revenue=Sort_df2[['Region','Item Type','Order Year','Order Quarter','Order Month','Units Sold','Total Revenue']]

# %%
Items_revenue.head(5)
# Out:
#                                Region        Item Type  Order Year  \
# 13  Central America and the Caribbean        Household        2017
# 33                               Asia        Household        2015
# 68                             Europe  Office Supplies        2010
# 75                      North America        Household        2014
# 38                               Asia  Office Supplies        2012
#
#     Order Quarter  Order Month  Units Sold  Total Revenue
# 13              3            8        8974     5997054.98
# 33              1            1        8250     5513227.50
# 68              4           10        8287     5396577.27
# 75              2            6        6954     4647149.58
# 38              1            1        6708     4368316.68

# %%
Items_revenue.tail(5)
# Out:
#                           Region      Item Type  Order Year  Order Quarter  \
# 47                        Europe  Personal Care        2010              4
# 23         Australia and Oceania         Fruits        2014              3
# 10                          Asia     Vegetables        2011              2
# 71  Middle East and North Africa         Fruits        2015              3
# 88  Middle East and North Africa         Fruits        2012              2
#
#     Order Month  Units Sold  Total Revenue
# 47           12         273       22312.29
# 23            8        2187       20404.71
# 10            6         124       19103.44
# 71            8         673        6279.09
# 88            4         522        4870.26

# %%
Sort_df3=df1.sort_values(by = ['Total Profit'], ascending=False)

# %%
Items_Profit=Sort_df3[['Region','Item Type','Order Year','Order Quarter','Order Month','Units Sold','Total Revenue','Total Profit']]

# %%
Items_Profit.head(5)
# Out:
#                                Region  Item Type  Order Year  Order Quarter  \
# 74       Middle East and North Africa  Cosmetics        2013              2
# 79              Australia and Oceania  Cosmetics        2013              3
# 46                             Europe  Cosmetics        2016              4
# 30                             Europe  Cosmetics        2012              3
# 13  Central America and the Caribbean  Household        2017              3
#
#     Order Month  Units Sold  Total Revenue  Total Profit
# 74            5        9892     4324782.40    1719922.04
# 79            7        9654     4220728.80    1678540.98
# 46           12        8867     3876652.40    1541705.29
# 30            9        8661     3786589.20    1505888.07
# 13            8        8974     5997054.98    1487261.02

# %%
Items_Profit.tail(5)
# Out:
#                           Region      Item Type  Order Year  Order Quarter  \
# 10                          Asia     Vegetables        2011              2
# 47                        Europe  Personal Care        2010              4
# 23         Australia and Oceania         Fruits        2014              3
# 71  Middle East and North Africa         Fruits        2015              3
# 88  Middle East and North Africa         Fruits        2012              2
#
#     Order Month  Units Sold  Total Revenue  Total Profit
# 10            6         124       19103.44       7828.12
# 47           12         273       22312.29       6841.38
# 23            8        2187       20404.71       5270.67
# 71            8         673        6279.09       1621.93
# 88            4         522        4870.26       1258.02

# %%
Year_wise=df1.sort_values( by = ['Order Month'])

# %%
Year_2010 = Year_wise[(Year_wise['Order Year'] ==2010)]

# %%
Year_2010
# Out:
#                           Region       Country        Item Type Sales Channel  \
# 50                        Europe       Albania          Clothes        Online
# 0          Australia and Oceania        Tuvalu        Baby Food       Offline
# 56         Australia and Oceania          Fiji          Clothes       Offline
# 41  Middle East and North Africa    Azerbaijan        Cosmetics        Online
# 27            Sub-Saharan Africa          Mali           Fruits        Online
# 68                        Europe     Lithuania  Office Supplies       Offline
# 63  Middle East and North Africa         Libya          Clothes       Offline
# 93                        Europe       Romania        Cosmetics        Online
# 47                        Europe   Switzerland    Personal Care        Online
# 18                          Asia  Turkmenistan        Household       Offline
#
#    Order Priority           Order Date   Order ID            Ship Date  \
# ...

# %%
Year_2011 = Year_wise[(Year_wise['Order Year'] ==2011)]

# %%
Year_2011
# Out:
#                                Region                           Country  \
# 86                 Sub-Saharan Africa             Sao Tome and Principe
# 83                 Sub-Saharan Africa                            Zambia
# 6                  Sub-Saharan Africa                            Angola
# 72                 Sub-Saharan Africa  Democratic Republic of the Congo
# 10                               Asia                        Kyrgyzstan
# 95                 Sub-Saharan Africa                              Mali
# 62                 Sub-Saharan Africa                          Cameroon
# 94  Central America and the Caribbean                         Nicaragua
# 77                               Asia                              Laos
# 96                               Asia                          Malaysia
# 36       Middle East and North Africa                             Syria
# 53                 Sub-Saharan Africa                      Sierra Leone
#
# ...

# %%
Year_2012 = Year_wise[(Year_wise['Order Year'] ==2012)]

# %%
Year_2012
# Out:
#                                Region         Country        Item Type  \
# 38                               Asia          Brunei  Office Supplies
# 39                             Europe        Bulgaria  Office Supplies
# 85                      North America          Mexico    Personal Care
# 84                 Sub-Saharan Africa           Kenya       Vegetables
# 15                             Europe        Bulgaria          Clothes
# 88       Middle East and North Africa          Kuwait           Fruits
# 58                             Europe  United Kingdom        Household
# 78                             Europe          Monaco        Baby Food
# 29                 Sub-Saharan Africa      The Gambia        Household
# 92       Middle East and North Africa      Azerbaijan  Office Supplies
# 43                             Europe        Slovakia       Vegetables
# 19              Australia and Oceania      East Timor             Meat
# ...

# %%
Year_2013 = Year_wise[(Year_wise['Order Year'] ==2013)]

# %%
Year_2013
# Out:
#                                Region                Country        Item Type  \
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 52       Middle East and North Africa           Saudi Arabia           Cereal
# 70                               Asia           Turkmenistan  Office Supplies
# 74       Middle East and North Africa               Pakistan        Cosmetics
# 61                             Europe             San Marino        Baby Food
# 79              Australia and Oceania                 Samoa         Cosmetics
# 51                 Sub-Saharan Africa                Lesotho           Fruits
# 60              Australia and Oceania              Australia           Cereal
# 54                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 64  Central America and the Caribbean                  Haiti        Cosmetics
# 65                 Sub-Saharan Africa                 Rwanda        Cosmetics
# ...

# %%
Year_2014 = Year_wise[(Year_wise['Order Year'] ==2014)]

# %%
Year_2014
# Out:
#                    Region                         Country        Item Type  \
# 2                  Europe                          Russia  Office Supplies
# 14                   Asia                        Mongolia    Personal Care
# 11     Sub-Saharan Africa                      Cape Verde          Clothes
# 87     Sub-Saharan Africa                      The Gambia        Baby Food
# 9      Sub-Saharan Africa                         Senegal           Cereal
# 20                 Europe                          Norway        Baby Food
# 75          North America                          Mexico        Household
# 3      Sub-Saharan Africa           Sao Tome and Principe           Fruits
# 59     Sub-Saharan Africa                        Djibouti        Cosmetics
# 91  Australia and Oceania                       Australia        Beverages
# 28                 Europe                          Norway        Beverages
# ...

# %%
Year_2015 = Year_wise[(Year_wise['Order Year'] ==2015)]

# %%
Year_2015
# Out:
#                           Region                Country        Item Type  \
# 17            Sub-Saharan Africa               Cameroon        Beverages
# 33                          Asia                Myanmar        Household
# 57                        Europe                Austria        Cosmetics
# 69            Sub-Saharan Africa             Madagascar          Clothes
# 5          Australia and Oceania        Solomon Islands        Baby Food
# 98                 North America                 Mexico    Personal Care
# 8             Sub-Saharan Africa  Republic of the Congo    Personal Care
# 21                        Europe               Portugal        Baby Food
# 71  Middle East and North Africa                  Libya           Fruits
# 32         Australia and Oceania              Australia  Office Supplies
# 44                          Asia                Myanmar          Clothes
#
#    Sales Channel Order Priority           Order Date   Order ID  \
# ...

# %%
Year_2016 = Year_wise[(Year_wise['Order Year'] ==2016)]

# %%
Year_2016
# Out:
#                                Region       Country        Item Type  \
# 97                 Sub-Saharan Africa  Sierra Leone       Vegetables
# 45                 Sub-Saharan Africa       Comoros           Cereal
# 22  Central America and the Caribbean      Honduras           Snacks
# 90                 Sub-Saharan Africa  Sierra Leone  Office Supplies
# 67  Central America and the Caribbean        Belize          Clothes
# 24                             Europe      Moldova     Personal Care
# 89                             Europe      Slovenia        Beverages
# 16                               Asia     Sri Lanka        Cosmetics
# 82       Middle East and North Africa          Iran        Cosmetics
# 46                             Europe       Iceland        Cosmetics
#
#    Sales Channel Order Priority           Order Date   Order ID  \
# 97       Offline              C  2016-01-06 00:00:00  728815257
# 45       Offline              H            3/29/2016  902102267
# ...

# %%
Year_2017 = Year_wise[(Year_wise['Order Year'] ==2017)]

# %%
Year_2017
# Out:
#                                Region     Country      Item Type  \
# 37                 Sub-Saharan Africa  The Gambia           Meat
# 12                               Asia  Bangladesh        Clothes
# 34                 Sub-Saharan Africa    Djibouti         Snacks
# 73                 Sub-Saharan Africa    Djibouti         Cereal
# 25                             Europe      France      Cosmetics
# 13  Central America and the Caribbean    Honduras      Household
# 35  Central America and the Caribbean  Costa Rica  Personal Care
# 40                 Sub-Saharan Africa       Niger  Personal Care
#
#    Sales Channel Order Priority           Order Date   Order ID  \
# 37        Online              M            1/14/2017  825304400
# 12        Online              L            1/13/2017  187310731
# 34        Online              M            2/25/2017  756274640
# 73        Online              H            5/20/2017  555990016
# ...

# %%
# !pip install openpyxl

# %%
df.to_excel('C:\\Users\\DELL\\Downloads\\AmazonSalesdataNEW.xlsx')
